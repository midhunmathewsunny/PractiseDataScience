# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('FL_insurance_sample.csv')

# %%
file.iloc[1]
# Out:
# policyID                   448094
# statecode                      FL
# county                CLAY COUNTY
# eq_site_limit         1.32238e+06
# hu_site_limit         1.32238e+06
# fl_site_limit         1.32238e+06
# fr_site_limit         1.32238e+06
# tiv_2011              1.32238e+06
# tiv_2012              1.43816e+06
# eq_site_deductible              0
# hu_site_deductible              0
# fl_site_deductible              0
# fr_site_deductible              0
# point_latitude            30.0639
# point_longitude          -81.7077
# line                  Residential
# construction              Masonry
# point_granularity               3
# Name: 1, dtype: object

# %%
len(file)
# Out:
# 36634

# %%
len(file.columns)
# Out:
# 18

# %%
file.index
# Out:
# RangeIndex(start=0, stop=36634, step=1)

# %%
list(file)
# Out:
# ['policyID',
#  'statecode',
#  'county',
#  'eq_site_limit',
#  'hu_site_limit',
#  'fl_site_limit',
#  'fr_site_limit',
#  'tiv_2011',
#  'tiv_2012',
#  'eq_site_deductible',
#  'hu_site_deductible',
#  'fl_site_deductible',
#  'fr_site_deductible',
#  'point_latitude',
#  'point_longitude',
#  'line',
#  'construction',
#  'point_granularity']

# %%
file.iloc[:5]
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
file['statecode'].iloc[:3]
# Out:
# 0    FL
# 1    FL
# 2    FL
# Name: statecode, dtype: object

# %%
file[file['county'] == 'CLAY COUNTY'].iloc[100:102]
# Out:
#      policyID statecode       county  eq_site_limit  hu_site_limit  \
# 309    565451        FL  CLAY COUNTY            0.0       22977.15
# 310    722334        FL  CLAY COUNTY            0.0       27572.58
#
#      fl_site_limit  fr_site_limit  tiv_2011  tiv_2012  eq_site_deductible  \
# 309            0.0            0.0  22977.15  31074.07                 0.0
# 310            0.0            0.0  27572.58  36234.34                 0.0
#
#      hu_site_deductible  fl_site_deductible  fr_site_deductible  \
# 309                 0.0                 0.0                   0
# 310                 0.0                 0.0                   0
#
#      point_latitude  point_longitude         line construction  \
# 309        30.00414       -81.700315  Residential         Wood
# 310        30.00421       -81.684000  Residential         Wood
#
#      point_granularity
# 309                  3
# 310                  3

# %%
newfile = file.groupby('county').sum()

# %%
newfile.to_csv('grouped_output')

# %%
pd.read_csv('grouped_output')
# Out:
#                  county    policyID  eq_site_limit  hu_site_limit  \
# 0        ALACHUA COUNTY   537179642   4.241348e+08   8.132216e+08
# 1          BAKER COUNTY    39400024   2.854645e+06   1.231170e+07
# 2            BAY COUNTY   232277083   6.402412e+08   1.058707e+09
# 3       BRADFORD COUNTY    17132221   3.727557e+07   4.044932e+07
# 4        BREVARD COUNTY   481992509   2.777074e+08   1.115282e+09
# 5        BROWARD COUNTY  1761094265   1.764811e+09   6.983013e+09
# 6        CALHOUN COUNTY    39113938   8.276625e+05   3.823511e+07
# 7      CHARLOTTE COUNTY   232903514   1.875581e+08   5.195757e+08
# 8         CITRUS COUNTY   208324736   2.958821e+08   3.496377e+08
# 9           CLAY COUNTY   200310519   1.714334e+07   2.232770e+08
# 10       COLLIER COUNTY   440154270   4.088169e+08   1.497875e+09
# 11      COLUMBIA COUNTY    70414824   6.556769e+06   1.794951e+08
# 12        DESOTO COUNTY    59308836   1.210767e+07   5.093566e+07
# ...
